# %%
import pandas as pd

# %%
rfm= pd.read_csv('/Users/t-2024-m0196/my-repo/Git/Git/실전프로젝트/실프_5일차_최종_amazon_customer.csv')
category= pd.read_csv('/Users/t-2024-m0196/my-repo/Git/Git/실전프로젝트/실프_4일차_태우님amz_category.csv')

# %%
rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36307 entries, 0 to 36306
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Custkey                           36307 non-null  int64
#  1   DateKey                           36307 non-null  object
#  2   Discount Amount                   36307 non-null  float64
#  3   Invoice Number                    36307 non-null  int64
#  4   Item                              36307 non-null  object
#  5   List Price                        36307 non-null  float64
#  6   Sales Amount                      36307 non-null  float64
#  7   Sales Amount Based on List Price  36307 non-null  float64
#  8   Sales Cost Amount                 36307 non-null  float64
#  9   Sales Margin Amount               36307 non-null  float64
#  10  Sales Price                       36307 non-null  float64
# ...

# %%
category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36307 entries, 0 to 36306
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Custkey                           36307 non-null  int64
#  1   DateKey                           36307 non-null  object
#  2   Discount Amount                   36307 non-null  float64
#  3   Invoice Date                      36307 non-null  object
#  4   Invoice Number                    36307 non-null  int64
#  5   Item Class                        32260 non-null  object
#  6   Item Number                       36307 non-null  object
#  7   Item                              36307 non-null  object
#  8   Line Number                       36307 non-null  int64
#  9   List Price                        36307 non-null  float64
#  10  Order Number                      36307 non-null  int64
# ...

# %%
# category= category.drop(columns=['Invoice Date', 'Item Class', 'Item Number', 'Promised Delivery Date', 'U/M'])

# %%
# category_only= category.drop(columns= ['DateKey', 'Discount Amount', 'Invoice Number', 'Line Number', 'List Price', 'Order Number', 'Sales Amount', 'Sales Amount Based on List Price', 'Sales Cost Amount', 'Sales Margin Amount', 'Sales Price', 'Sales Quantity', 'Sales Rep', 'dk'])

# %%
category_week= category[['Item Last', 'Category', 'wd', 'weekday']]

# %%
amazon_merged= pd.concat([rfm, category_week])
amazon_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72614 entries, 0 to 36306
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Custkey                           36307 non-null  float64
#  1   DateKey                           36307 non-null  object
#  2   Discount Amount                   36307 non-null  float64
#  3   Invoice Number                    36307 non-null  float64
#  4   Item                              36307 non-null  object
#  5   List Price                        36307 non-null  float64
#  6   Sales Amount                      36307 non-null  float64
#  7   Sales Amount Based on List Price  36307 non-null  float64
#  8   Sales Cost Amount                 36307 non-null  float64
#  9   Sales Margin Amount               36307 non-null  float64
#  10  Sales Price                       36307 non-null  float64
# ...

# %%
amazon_merged['Category'].value_counts()
# Out:
# Category
# Vegetable    5716
# Dairy        4934
# Mealkits     4715
# Snack        3791
# Seafood      3192
# Beverage     2842
# Condiment    2308
# Bakery       2197
# Fruit        2196
# Meat         2096
# Nuts         1300
# Alchol        874
# Coffee        146
# Name: count, dtype: int64

# %%
# print(rfm['Custkey'] == category['Custkey'])

# %%
# rfm['Custkey'].head(10)

# %%
# category['Custkey'].head(10)

# %%
rfm['Grade'].value_counts()
# Out:
# Grade
# silver      15615
# gold         8694
# platinum     7346
# diamond      2645
# family       2007
# Name: count, dtype: int64

# %%
rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36307 entries, 0 to 36306
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Custkey                           36307 non-null  int64
#  1   DateKey                           36307 non-null  object
#  2   Discount Amount                   36307 non-null  float64
#  3   Invoice Number                    36307 non-null  int64
#  4   Item                              36307 non-null  object
#  5   List Price                        36307 non-null  float64
#  6   Sales Amount                      36307 non-null  float64
#  7   Sales Amount Based on List Price  36307 non-null  float64
#  8   Sales Cost Amount                 36307 non-null  float64
#  9   Sales Margin Amount               36307 non-null  float64
#  10  Sales Price                       36307 non-null  float64
# ...

# %%
print(sum(rfm['Sales Amount'][rfm['Grade'] == 'diamond']) / sum(rfm['Sales Amount']))
print(sum(rfm['Sales Amount'][rfm['Grade'] == 'platinum']) / sum(rfm['Sales Amount']))
print(sum(rfm['Sales Amount'][rfm['Grade'] == 'gold']) / sum(rfm['Sales Amount']))
print(sum(rfm['Sales Amount'][rfm['Grade'] == 'silver']) / sum(rfm['Sales Amount']))
print(sum(rfm['Sales Amount'][rfm['Grade'] == 'family']) / sum(rfm['Sales Amount']))
# Out:
# 0.05974705566765083
# 0.20984354110211642
# 0.33663199801043786
# 0.35346617981942274
# 0.04031122540037215

# %%
print(sum(rfm['Invoice Number'][rfm['Grade'] == 'diamond']) / sum(rfm['Invoice Number']))
print(sum(rfm['Invoice Number'][rfm['Grade'] == 'platinum']) / sum(rfm['Invoice Number']))
print(sum(rfm['Invoice Number'][rfm['Grade'] == 'gold']) / sum(rfm['Invoice Number']))
print(sum(rfm['Invoice Number'][rfm['Grade'] == 'silver']) / sum(rfm['Invoice Number']))
print(sum(rfm['Invoice Number'][rfm['Grade'] == 'family']) / sum(rfm['Invoice Number']))
# Out:
# 0.08219445430476302
# 0.21539714532918147
# 0.24127423630109995
# 0.3963858250598239
# 0.06474833900513162

# %%
rfm['Grade'].value_counts()
# Out:
# Grade
# silver      15615
# gold         8694
# platinum     7346
# diamond      2645
# family       2007
# Name: count, dtype: int64

# %%
rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36307 entries, 0 to 36306
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Custkey                           36307 non-null  int64
#  1   DateKey                           36307 non-null  object
#  2   Discount Amount                   36307 non-null  float64
#  3   Invoice Number                    36307 non-null  int64
#  4   Item                              36307 non-null  object
#  5   List Price                        36307 non-null  float64
#  6   Sales Amount                      36307 non-null  float64
#  7   Sales Amount Based on List Price  36307 non-null  float64
#  8   Sales Cost Amount                 36307 non-null  float64
#  9   Sales Margin Amount               36307 non-null  float64
#  10  Sales Price                       36307 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 3))

sns.violinplot(data= rfm, y='Sales Amount', x = 'Grade', palette='viridis')
# Out:
# /var/folders/v7/v961g5xd3bj5j5xzyv_25fpc0000gn/T/ipykernel_18297/1620309427.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data= rfm, y='Sales Amount', x = 'Grade', palette='viridis')
# <Axes: xlabel='Grade', ylabel='Sales Amount'>

# %%
rfm_qcut= pd.read_csv('./rfm_qcut.csv')

# %%
rfm_qcut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529 entries, 0 to 528
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       529 non-null    int64
#  1   Custkey          529 non-null    int64
#  2   Recency          529 non-null    float64
#  3   Frequency        529 non-null    int64
#  4   Monetary         529 non-null    float64
#  5   Recency_pt_mm    529 non-null    float64
#  6   Frequency_pt_mm  529 non-null    float64
#  7   Monetary_pt_mm   529 non-null    float64
#  8   Cluster          529 non-null    int64
#  9   R                529 non-null    int64
#  10  F                529 non-null    int64
#  11  M                529 non-null    int64
#  12  RFM_score        529 non-null    int64
#  13  RFM_class        529 non-null    object
# dtypes: float64(5), int64(8), object(1)
# memory usage: 58.0+ KB

# %%
amazoned= pd.read_csv('./amazon_이상치처리.csv')
rfm_qcut_concat= pd.merge(amazoned, rfm_qcut, on= 'Custkey')
rfm_qcut_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62103 entries, 0 to 62102
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Custkey                           62103 non-null  int64
#  1   DateKey                           62103 non-null  object
#  2   Discount Amount                   62103 non-null  float64
#  3   Invoice Date                      62103 non-null  object
#  4   Invoice Number                    62103 non-null  int64
#  5   Item                              62103 non-null  object
#  6   Line Number                       62103 non-null  int64
#  7   List Price                        62103 non-null  float64
#  8   Order Number                      62103 non-null  int64
#  9   Sales Amount                      62103 non-null  float64
#  10  Sales Amount Based on List Price  62103 non-null  float64
# ...

# %%
amazon = amazoned[amazoned['Discount Amount'] >=0]

# %%
amazoned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64223 entries, 0 to 64222
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Custkey                           64223 non-null  int64
#  1   DateKey                           64223 non-null  object
#  2   Discount Amount                   64223 non-null  float64
#  3   Invoice Date                      64223 non-null  object
#  4   Invoice Number                    64223 non-null  int64
#  5   Item                              64223 non-null  object
#  6   Line Number                       64223 non-null  int64
#  7   List Price                        64223 non-null  float64
#  8   Order Number                      64223 non-null  int64
#  9   Sales Amount                      64223 non-null  float64
#  10  Sales Amount Based on List Price  64223 non-null  float64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 3))

sns.violinplot(data= rfm_qcut, y='Monetary_pt_mm', x = 'RFM_class', palette='viridis')
# Out:
# /var/folders/v7/v961g5xd3bj5j5xzyv_25fpc0000gn/T/ipykernel_18297/1435335090.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data= rfm_qcut, y='Monetary_pt_mm', x = 'RFM_class', palette='viridis')
# <Axes: xlabel='RFM_class', ylabel='Monetary_pt_mm'>

# %%
rfm_qcut.columns
# Out:
# Index(['Unnamed: 0', 'Custkey', 'Recency', 'Frequency', 'Monetary',
#        'Recency_pt_mm', 'Frequency_pt_mm', 'Monetary_pt_mm', 'Cluster', 'R',
#        'F', 'M', 'RFM_score', 'RFM_class'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 3))

sns.violinplot(data= rfm_qcut, y='Recency_pt_mm', x = 'RFM_class', palette='viridis')
# Out:
# /var/folders/v7/v961g5xd3bj5j5xzyv_25fpc0000gn/T/ipykernel_18297/491850288.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data= rfm_qcut, y='Recency_pt_mm', x = 'RFM_class', palette='viridis')
# <Axes: xlabel='RFM_class', ylabel='Recency_pt_mm'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 3))

sns.violinplot(data= rfm_qcut, y='Frequency_pt_mm', x = 'RFM_class', palette='viridis')
# Out:
# /var/folders/v7/v961g5xd3bj5j5xzyv_25fpc0000gn/T/ipykernel_18297/378279605.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data= rfm_qcut, y='Frequency_pt_mm', x = 'RFM_class', palette='viridis')
# <Axes: xlabel='RFM_class', ylabel='Frequency_pt_mm'>
