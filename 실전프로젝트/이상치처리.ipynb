# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
amazon = pd.read_csv('/Users/t-2024-m0196/my-repo/Git/실전프로젝트/AmazonFoodCategory Dataset.csv')
print(amazon.info())
amazon.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65280 entries, 0 to 65279
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Custkey                           65280 non-null  int64
#  1   DateKey                           65280 non-null  object
#  2   Discount Amount                   65278 non-null  float64
#  3   Invoice Date                      65280 non-null  object
#  4   Invoice Number                    65280 non-null  int64
#  5   Item Class                        56995 non-null  object
#  6   Item Number                       65240 non-null  object
#  7   Item                              65280 non-null  object
#  8   Line Number                       65280 non-null  int64
#  9   List Price                        65280 non-null  float64
#  10  Order Number                      65280 non-null  int64
# ...

# %%
amazon = amazon[amazon['Discount Amount'] >= 0]
# amazon= amazon[amazon['Sales Price'] > 0]
# amazon= amazon[amazon['Sales Quantity'] > 0]
# amazon= amazon[amazon['Sales Amount'] > 0]
# amazon= amazon[amazon['Sales Amount Based on List Price'] > 0]

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64427 entries, 0 to 65279
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Custkey                           64427 non-null  int64
#  1   DateKey                           64427 non-null  object
#  2   Discount Amount                   64427 non-null  float64
#  3   Invoice Date                      64427 non-null  object
#  4   Invoice Number                    64427 non-null  int64
#  5   Item Class                        56912 non-null  object
#  6   Item Number                       64427 non-null  object
#  7   Item                              64427 non-null  object
#  8   Line Number                       64427 non-null  int64
#  9   List Price                        64427 non-null  float64
#  10  Order Number                      64427 non-null  int64
# ...

# %%
amazon= amazon.drop(columns= 'Item Number')
amazon = amazon.drop(columns= 'Item Class')
amazon = amazon.drop(columns= 'Promised Delivery Date')

# %%
amazon.isna().sum()
# Out:
# Custkey                             0
# DateKey                             0
# Discount Amount                     0
# Invoice Date                        0
# Invoice Number                      0
# Item                                0
# Line Number                         0
# List Price                          0
# Order Number                        0
# Sales Amount                        0
# Sales Amount Based on List Price    0
# Sales Cost Amount                   0
# Sales Margin Amount                 0
# Sales Price                         0
# Sales Quantity                      0
# Sales Rep                           0
# U/M                                 0
# dtype: int64

# %%
sns.histplot(amazon['Sales Cost Amount'])
# Out:
# <Axes: xlabel='Sales Cost Amount', ylabel='Count'>

# %%
amazon[amazon['Sales Cost Amount']==0]
# Out:
#         Custkey     DateKey  Discount Amount Invoice Date  Invoice Number  \
# 332    10026839  12/29/2019            20.64   2019/12/29          329348
# 493    10015495  12/28/2019            10.70   2019/12/28          329238
# 647    10017036  12/27/2019           413.22   2019/12/27          329126
# 1842   10026522   12/9/2019            94.23   2019/12/09          327531
# 1843   10026522   12/9/2019           406.53   2019/12/09          327531
# ...         ...         ...              ...          ...             ...
# 61059  10009633   2/22/2017            83.66   2017/02/22          123515
# 63907  10009645   1/11/2017             0.00   2017/01/11          119774
# 64213  10009645   1/10/2017             0.00   2017/01/10          119664
# 64501  10022732    1/9/2017           643.13   2017/01/09          119657
# 64970  10002144    1/3/2017           709.77   2017/01/03          329737
#
#                                 Item  Line Number  List Price  Order Number  \
# ...

# %%
temp = amazon[amazon['Sales Cost Amount']==0]

(temp['Sales Amount'] == temp['Sales Margin Amount']).sum()
# Out:
# np.int64(204)

# %%
amazon[amazon['Sales Cost Amount']>0]
# Out:
#         Custkey     DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0      10016609  12/31/2019         398.7300   2019/12/31          329568
# 1      10016609  12/31/2019         268.6700   2019/12/31          329569
# 2      10016609  12/31/2019         398.7300   2019/12/31          329569
# 3      10016609  12/31/2019         466.4500   2019/12/31          329569
# 4      10016609  12/31/2019         515.5100   2019/12/31          329569
# ...         ...         ...              ...          ...             ...
# 65275  10025919    1/1/2017         466.3700   2017/01/01          119182
# 65276  10009985    1/1/2017         783.9700   2017/01/01          119186
# 65277  10025552    1/1/2017        1309.5297   2017/01/01          119192
# 65278  10025025    1/1/2017         222.6500   2017/01/01          119197
# 65279  10022750    1/1/2017         180.2700   2017/01/01          119202
#
#                                   Item  Line Number  List Price  Order Number  \
# ...

# %%
amazon = amazon[amazon['Sales Cost Amount'] > 0]

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64223 entries, 0 to 65279
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Custkey                           64223 non-null  int64
#  1   DateKey                           64223 non-null  object
#  2   Discount Amount                   64223 non-null  float64
#  3   Invoice Date                      64223 non-null  object
#  4   Invoice Number                    64223 non-null  int64
#  5   Item                              64223 non-null  object
#  6   Line Number                       64223 non-null  int64
#  7   List Price                        64223 non-null  float64
#  8   Order Number                      64223 non-null  int64
#  9   Sales Amount                      64223 non-null  float64
#  10  Sales Amount Based on List Price  64223 non-null  float64
# ...

# %%
set(amazon[amazon['List Price'] > 1000]['Item'])

# 데이터 자체의 오류라 생각하고... 담당자의 소수점 이슈가 있었다
# -> 0.01 곱하기??
# 재고 처리할 때 소수점 안붙임~~~ 
# 1000넘는 것들은 

# 프로젝트를 하는 건 분석을 하는 것.
# 경향성 파악. 등 데이터 분석을 한 다음에 
# 경향성이 없다고 하면 그때 해도 늦진 않을 것 같음
#
# Out:
# {'Atomic Mint Chocolate Bar',
#  'BBB Best Extra Chunky Peanut Butter',
#  'BBB Best Grape Jelly',
#  'Best Choice Fudge Brownies',
#  'Best Choice Fudge Cookies',
#  'Best Choice Graham Crackers',
#  'Best Choice Potato Chips',
#  'Better Fancy Canned Sardines',
#  'Better Noodle Soup',
#  'Big Time Popsicles',
#  'Bravo Canned String Beans',
#  'Carlson Head Cheese',
#  'Club Havarti Cheese',
#  'Club Head Cheese',
#  'Club Low Fat String Cheese',
#  'Club Sour Cream',
#  'Club String Cheese',
#  'Cutting Edge Sliced Chicken',
#  'Cutting Edge Sliced Ham',
#  'Discover Manicotti',
#  'Discover Spaghetti',
#  'Ebony Squash',
#  'Even Better 1% Milk',
#  'Even Better 2% Milk',
#  'Even Better Blueberry Yogurt',
#  'Even Better Buttermilk',
#  'Even Better Chocolate Milk',
#  'Even Better Jack Cheese',
#  'Even Better Large Curd Cottage Cheese',
#  'Even Better Mild Cheddar Cheese',
#  'Even Better Muenster Cheese',
#  'Even Better Sharp Cheddar Cheese',
# ...

# %%
sns.histplot(amazon['List Price'], kde= True)
# 유의미한 데이터들일 것 같음
# 1000으로 무 자르듯이 자르는 건 위험할 것 같음.

# 화폐가 달러가 아닐수도. 화폐 단위.
# 분포를 봤을 때 무의미한 데이터는 아닌 것 같다.


# 이상치 제거하려는 목적이 우선 : 이상치라고 보일만한 것도 없음.
# 지금 데이터에서 이상치라고 보이는 건 없긴 함.
# 목적이 생겼으면 그때 하는 것이 나을 듯.
# Out:
# <Axes: xlabel='List Price', ylabel='Count'>

# %%
amazon['List Price'].describe()
# 냅두는 건 냅두는데 해석할때의 문제
#
# Out:
# count    64223.000000
# mean       520.051435
# std        448.754013
# min          0.392900
# 25%        187.010000
# 50%        345.000000
# 75%        817.680000
# max       2760.700000
# Name: List Price, dtype: float64

# %%
amazon['Sales Price'].describe()
# Out:
# count    64223.000000
# mean       283.621855
# std        246.720424
# min          0.337341
# 25%        100.329091
# 50%        183.763333
# 75%        448.220000
# max       1431.230000
# Name: Sales Price, dtype: float64

# %%
sns.histplot(amazon['Sales Price'], kde= True)
# Out:
# <Axes: xlabel='Sales Price', ylabel='Count'>

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64223 entries, 0 to 65279
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Custkey                           64223 non-null  int64
#  1   DateKey                           64223 non-null  object
#  2   Discount Amount                   64223 non-null  float64
#  3   Invoice Date                      64223 non-null  object
#  4   Invoice Number                    64223 non-null  int64
#  5   Item                              64223 non-null  object
#  6   Line Number                       64223 non-null  int64
#  7   List Price                        64223 non-null  float64
#  8   Order Number                      64223 non-null  int64
#  9   Sales Amount                      64223 non-null  float64
#  10  Sales Amount Based on List Price  64223 non-null  float64
# ...

# %%
amazon= amazon.reset_index(drop= True)

# %%
amazon.head()
# Out:
#     Custkey     DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10016609  12/31/2019           398.73   2019/12/31          329568
# 1  10016609  12/31/2019           268.67   2019/12/31          329569
# 2  10016609  12/31/2019           398.73   2019/12/31          329569
# 3  10016609  12/31/2019           466.45   2019/12/31          329569
# 4  10016609  12/31/2019           515.51   2019/12/31          329569
#
#                          Item  Line Number  List Price  Order Number  \
# 0         Super Vegetable Oil         1000      163.47        122380
# 1  Golden Fajita French Fries         7000      275.37        123966
# 2         Super Vegetable Oil         4000      163.47        123966
# 3            High Top Oranges         3000      119.52        123966
# 4       Tell Tale New Potatos         9000      264.18        123966
#
#    Sales Amount  Sales Amount Based on List Price  Sales Cost Amount  \
# ...

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64223 entries, 0 to 64222
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Custkey                           64223 non-null  int64
#  1   DateKey                           64223 non-null  object
#  2   Discount Amount                   64223 non-null  float64
#  3   Invoice Date                      64223 non-null  object
#  4   Invoice Number                    64223 non-null  int64
#  5   Item                              64223 non-null  object
#  6   Line Number                       64223 non-null  int64
#  7   List Price                        64223 non-null  float64
#  8   Order Number                      64223 non-null  int64
#  9   Sales Amount                      64223 non-null  float64
#  10  Sales Amount Based on List Price  64223 non-null  float64
# ...

# %%
amazon.to_csv('amazon.csv', index= False)
