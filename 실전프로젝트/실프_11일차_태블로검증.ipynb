# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
category= pd.read_csv('/Users/t-2024-m0196/my-repo/Git/Git/실전프로젝트/실프_10일차_태우님amz_categories.csv')

# %%
category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36307 entries, 0 to 36306
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Custkey                           36307 non-null  int64
#  1   DateKey                           36307 non-null  object
#  2   Discount Amount                   36307 non-null  float64
#  3   Invoice Date                      36307 non-null  object
#  4   Invoice Number                    36307 non-null  int64
#  5   Item Class                        32260 non-null  object
#  6   Item Number                       36307 non-null  object
#  7   Item                              36307 non-null  object
#  8   Line Number                       36307 non-null  int64
#  9   List Price                        36307 non-null  float64
#  10  Order Number                      36307 non-null  int64
# ...

# %%
plt.pie(category['weekday'].value_counts(), labels=category['weekday'].value_counts().index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x114eab230>,
# ...
#  [Text(0.8557892293479711, 0.6911040405988131, 'Mon'),
#   Text(-0.4512822237904263, 1.0031671617884867, 'Sat'),
#   Text(-1.0927674058989256, -0.1259340962763178, 'Sun'),
#   Text(-0.2579440344664698, -1.0693291705939574, 'Fri'),
#   Text(0.7406208364360872, -0.8133146848770842, 'Thu'),
#   Text(1.0708609872822048, -0.25150893804591107, 'Tue'),
#   Text(1.0999762133813202, -0.0072339474211918385, 'Wed')],
#  [Text(0.4667941250988933, 0.3769658403266253, '21.6%'),
#   Text(-0.2461539402493234, 0.5471820882482654, '20.2%'),
#   Text(-0.5960549486721413, -0.06869132524162788, '20.0%'),
#   Text(-0.14069674607261987, -0.5832704566876131, '18.8%'),
#   Text(0.4039750016924112, -0.4436261917511368, '12.2%'),
#   Text(0.5841059930630207, -0.13718669347958784, '6.9%'),
#   Text(0.59998702548072, -0.003945789502468275, '0.2%')])

# %%
tran= pd.read_csv('/Users/t-2024-m0196/my-repo/Git/Git/실전프로젝트/실프_10일차_태우님_RFM클러스터_customer요약정보amz_customer.csv')

tran.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529 entries, 0 to 528
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Custkey               529 non-null    int64
#  1   RFM_score             529 non-null    float64
#  2   RFM_class             529 non-null    object
#  3   Recency               529 non-null    int64
#  4   Usage Date Count      529 non-null    int64
#  5   Transaction Count     529 non-null    int64
#  6   Usage Term            529 non-null    int64
#  7   Average Usage Term    529 non-null    float64
#  8   Sales Amount          529 non-null    float64
#  9   Sales Quantity        529 non-null    int64
#  10  Sales Margin Amount   529 non-null    float64
#  11  Average Basket Size   529 non-null    int64
#  12  Average Sales Amount  529 non-null    int64
#  13  New User              529 non-null    int64
#  14  Active User           529 non-null    int64
# ...
